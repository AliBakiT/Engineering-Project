# %%
import numpy as np
import os
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
from google.colab import drive

# Google Drive bağlantısını oluştur
drive.mount('/content/gdrive')

# Klasör yollarını tanımlayın
healthy_dir = "/content/gdrive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Deneme_50_PNG/224x224/BlackBox/Normal"
otoxyn_dir = "/content/gdrive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Deneme_50_PNG/224x224/BlackBox/Okralı"

# Görüntüleri yükleyip ön işleme yapacak fonksiyon
def load_images(folder):
    images = []
    for filename in os.listdir(folder):
        if filename.endswith('.png'):
            img_path = os.path.join(folder, filename)
            img = image.load_img(img_path, target_size=(224, 224))
            img_array = image.img_to_array(img)
            img_array = preprocess_input(img_array)
            images.append(img_array)
    return images

# Verileri yükle
healthy_images = load_images(healthy_dir)
otoxyn_images = load_images(otoxyn_dir)

# Etiketleri oluştur ve one-hot encoding yap
labels = [0] * len(healthy_images) + [1] * len(otoxyn_images)
labels = to_categorical(labels)

# Verileri ve etiketleri birleştir
data = np.array(healthy_images + otoxyn_images)

# Eğitim ve test setlerine ayır
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# ResNet-50 modelini yükle
base_model = ResNet50(weights='imagenet', include_top=False)

# Modeli özelleştir
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(2, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# Sadece son katmanları eğit
for layer in base_model.layers:
    layer.trainable = False

# Modeli derle
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Modeli eğit
model.fit(X_train, y_train, batch_size=32, epochs=10, validation_data=(X_test, y_test))

# Modelin doğruluğunu değerlendir
scores = model.evaluate(X_test, y_test)
print(f'Model Accuracy: {scores[1]:.2f}')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Epoch 1/10
# 3/3 [==============================] - 25s 7s/step - loss: 4.3197 - accuracy: 0.4750 - val_loss: 0.7908 - val_accuracy: 0.6000
# Epoch 2/10
# 3/3 [==============================] - 27s 10s/step - loss: 1.3207 - accuracy: 0.6250 - val_loss: 3.4890 - val_accuracy: 0.4000
# Epoch 3/10
# 3/3 [==============================] - 19s 7s/step - loss: 1.9363 - accuracy: 0.5500 - val_loss: 0.8142 - val_accuracy: 0.6000
# Epoch 4/10
# 3/3 [==============================] - 26s 9s/step - loss: 1.3150 - accuracy: 0.4750 - val_loss: 0.5067 - val_accuracy: 0.7500
# Epoch 5/10
# 3/3 [==============================] - 19s 6s/step - loss: 0.6361 - accuracy: 0.6500 - val_loss: 1.4352 - val_accuracy: 0.4000
# Epoch 6/10
# 3/3 [==============================] - 21s 7s/step - loss: 0.9097 - accuracy: 0.5750 - val_loss: 0.5182 - val_accuracy: 0.7500
# Epoch 7/10
# 3/3 [==============================] - 21s 8s/step - loss: 0.7324 - accuracy: 0.6750 - val_loss: 0.5410 - val_accuracy: 0.7500
# Epoch 8/10
# 3/3 [==============================] - 23s 7s/step - loss: 0.5809 - accuracy: 0.7250 - val_loss: 0.9533 - val_accuracy: 0.7000
# Epoch 9/10
# 3/3 [==============================] - 21s 8s/step - loss: 0.6616 - accuracy: 0.6875 - val_loss: 0.5776 - val_accuracy: 0.6500
# Epoch 10/10
# 3/3 [==============================] - 21s 7s/step - loss: 0.4873 - accuracy: 0.7500 - val_loss: 0.6037 - val_accuracy: 0.7500
# 1/1 [==============================] - 4s 4s/step - loss: 0.6037 - accuracy: 0.7500
# Model Accuracy: 0.75

# %% [markdown]
# 1) 0.75
#
# 2) 0.60
#
# 3) 0.60
#
# 4) 0.75
#
# 5) 0.70
#
# 6)0.75

# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
from google.colab import drive

# Rastgeleliğe global seed ayarla
np.random.seed(42)
tf.random.set_seed(42)

# Google Drive bağlantısını oluştur
drive.mount('/content/gdrive')

# Klasör yollarını tanımla
healthy_dir = "/content/gdrive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Deneme_50_PNG/224x224/BlackBox/Normal"
otoxyn_dir = "/content/gdrive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Deneme_50_PNG/224x224/BlackBox/Okralı"

# Görüntüleri yükleyip ön işleme yapacak fonksiyon
def load_images(folder):
    images = []
    for filename in os.listdir(folder):
        if filename.endswith('.png'):
            img_path = os.path.join(folder, filename)
            img = image.load_img(img_path, target_size=(224, 224))
            img_array = image.img_to_array(img)
            img_array = preprocess_input(img_array)
            images.append(img_array)
    return images

# Verileri yükle
healthy_images = load_images(healthy_dir)
otoxyn_images = load_images(otoxyn_dir)

# Etiketleri oluştur ve one-hot encoding yap
labels = [0] * len(healthy_images) + [1] * len(otoxyn_images)
labels = to_categorical(labels)

# Verileri ve etiketleri birleştir
data = np.array(healthy_images + otoxyn_images)

# Eğitim ve test setlerine ayır
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Yeni model oluşturup derleme fonksiyonu
def create_model():
    base_model = ResNet50(weights='imagenet', include_top=False)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    predictions = Dense(2, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    for layer in base_model.layers:
        layer.trainable = True
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Yeni modeli oluştur ve derle
model = create_model()

# Modeli eğit
model.fit(X_train, y_train, batch_size=32, epochs=20, validation_data=(X_test, y_test))

# Modelin doğruluğunu değerlendir
scores = model.evaluate(X_test, y_test)
print(f'Model Accuracy: {scores[1]:.2f}')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Epoch 1/20
# 3/3 [==============================] - 96s 22s/step - loss: 3.8711 - accuracy: 0.5250 - val_loss: 3.9720 - val_accuracy: 0.4000
# Epoch 2/20
# 3/3 [==============================] - 62s 19s/step - loss: 1.7722 - accuracy: 0.5750 - val_loss: 0.4687 - val_accuracy: 0.7000
# Epoch 3/20
# 3/3 [==============================] - 64s 19s/step - loss: 0.5026 - accuracy: 0.7625 - val_loss: 1.3045 - val_accuracy: 0.5500
# Epoch 4/20
# 3/3 [==============================] - 60s 19s/step - loss: 0.4328 - accuracy: 0.7875 - val_loss: 5.0795 - val_accuracy: 0.4000
# Epoch 5/20
# 3/3 [==============================] - 64s 21s/step - loss: 0.4391 - accuracy: 0.8125 - val_loss: 17.0337 - val_accuracy: 0.4000
# Epoch 6/20
# 3/3 [==============================] - 60s 18s/step - loss: 0.3026 - accuracy: 0.8875 - val_loss: 102.2256 - val_accuracy: 0.4000
# Epoch 7/20
# 3/3 [==============================] - 64s 20s/step - loss: 0.3289 - accuracy: 0.8125 - val_loss: 203.2713 - val_accuracy: 0.4000
# Epoch 8/20
# 3/3 [==============================] - 61s 19s/step - loss: 0.3229 - accuracy: 0.7875 - val_loss: 345.2625 - val_accuracy: 0.4000
# Epoch 9/20
# 3/3 [==============================] - 63s 20s/step - loss: 0.2197 - accuracy: 0.9375 - val_loss: 1025.6404 - val_accuracy: 0.4000
# Epoch 10/20
# 3/3 [==============================] - 64s 20s/step - loss: 0.1468 - accuracy: 0.9750 - val_loss: 971.4022 - val_accuracy: 0.4000
# Epoch 11/20
# 3/3 [==============================] - 67s 20s/step - loss: 0.0667 - accuracy: 0.9875 - val_loss: 648.4675 - val_accuracy: 0.4000
# Epoch 12/20
# 3/3 [==============================] - 64s 20s/step - loss: 0.0285 - accuracy: 0.9875 - val_loss: 880.1697 - val_accuracy: 0.4000
# Epoch 13/20
# 3/3 [==============================] - 63s 20s/step - loss: 0.3289 - accuracy: 0.9125 - val_loss: 453.3647 - val_accuracy: 0.4000
# Epoch 14/20
# 3/3 [==============================] - 64s 20s/step - loss: 0.1504 - accuracy: 0.9500 - val_loss: 75.5440 - val_accuracy: 0.7000
# Epoch 15/20
# 3/3 [==============================] - 62s 20s/step - loss: 0.2256 - accuracy: 0.9000 - val_loss: 341.6115 - val_accuracy: 0.6000
# Epoch 16/20
# 3/3 [==============================] - 62s 20s/step - loss: 0.2482 - accuracy: 0.8875 - val_loss: 674.5739 - val_accuracy: 0.6000
# Epoch 17/20
# 3/3 [==============================] - 62s 20s/step - loss: 0.2076 - accuracy: 0.9000 - val_loss: 1683.2601 - val_accuracy: 0.6000
# Epoch 18/20
# 3/3 [==============================] - 62s 19s/step - loss: 0.1174 - accuracy: 0.9750 - val_loss: 1442.0525 - val_accuracy: 0.6000
# Epoch 19/20
# 3/3 [==============================] - 64s 20s/step - loss: 0.0905 - accuracy: 1.0000 - val_loss: 530.2769 - val_accuracy: 0.6000
# Epoch 20/20
# 3/3 [==============================] - 61s 19s/step - loss: 0.0683 - accuracy: 1.0000 - val_loss: 189.7459 - val_accuracy: 0.6000
# 1/1 [==============================] - 6s 6s/step - loss: 189.7459 - accuracy: 0.6000
# Model Accuracy: 0.60

# %%
1) 0.65
2) 0.70
3)0.65
4) 0.75
5) 0.60
6) 0.70
7) 0.70
8) 0.75
9) 0.70
10) 0.60
