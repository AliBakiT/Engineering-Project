# %%
# Google Drive'ı bağlama
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Pretreined Model Run

# %%
import os
import numpy as np
from sklearn.metrics import accuracy_score, log_loss
from keras.preprocessing.image import load_img, img_to_array
from keras.utils import to_categorical
from tensorflow.keras.models import load_model

# Okra ve normal klasörlerinin yolları
okra_klasoru = r"F:\PNG_Datasets\700_Sinirsiz_Cift\200_Test\Okrali"
normal_klasoru = r"F:\PNG_Datasets\700_Sinirsiz_Cift\200_Test\Saglikli"

# Verileri ve etiketleri depolamak için boş listeler
X = []
y = []

# Okra verilerini yükleme ve etiketleme
for dosya_adi in os.listdir(okra_klasoru):
    dosya_yolu = os.path.join(okra_klasoru, dosya_adi)
    img = load_img(dosya_yolu, target_size=(512, 512))
    img_array = img_to_array(img)
    X.append(img_array)
    y.append(0)  # Okra sınıfı

# Normal verilerini yükleme ve etiketleme
for dosya_adi in os.listdir(normal_klasoru):
    dosya_yolu = os.path.join(normal_klasoru, dosya_adi)
    img = load_img(dosya_yolu, target_size=(512, 512))
    img_array = img_to_array(img)
    X.append(img_array)
    y.append(1)  # Normal sınıfı

# Veriyi ve etiketleri Numpy dizilerine dönüştürme
X = np.array(X)
y = np.array(y)

# Verileri karıştırma
sirali_indeksler = np.arange(X.shape[0])
np.random.shuffle(sirali_indeksler)
X = X[sirali_indeksler]
y = y[sirali_indeksler]

# Modeli yükleyip verileri tahmin etme
model = load_model(r"C:\Users\AliBakiTURKOZ\Downloads\Deneme_Çift_Sinirsiz_CNN_Model_1_.h5", compile = False)
predictions = model.predict(X)  # Verileri tahmin etme

# Gerçek etiketlerin ve tahminlerin hazırlanması
true_labels = y
true_labels_cat = to_categorical(true_labels, num_classes=2)  # Gerçek etiketlerin kategorik hale getirilmesi
pred_prob_cat = predictions  # Tahmin olasılıklarının hesaplanması

# Doğruluk oranını ve kaybı hesaplama
accuracy = accuracy_score(true_labels, np.argmax(predictions, axis=1))
loss = log_loss(true_labels_cat, pred_prob_cat)

print(f"Doğruluk Oranı: {accuracy}")
print(f"Kayıp: {loss}")
# Out:
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 805ms/step
# Doğruluk Oranı: 0.825
# Kayıp: 0.40887038450200536

# %%
# Normalize edilmiş Veriler ile test kodu

import os
import numpy as np
from sklearn.metrics import accuracy_score, log_loss
from keras.preprocessing.image import load_img, img_to_array
from keras.utils import to_categorical
from tensorflow.keras.models import load_model

# Okra ve normal klasörlerinin yolları
okra_klasoru = "/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Çift_Grafikler/700_Sinirli_Cift/200_Test/Okrali"
normal_klasoru = "/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Çift_Grafikler/700_Sinirli_Cift/200_Test/Saglikli"

# Verileri ve etiketleri depolamak için boş listeler
X = []
y = []

# Okra verilerini yükleme ve etiketleme
for dosya_adi in os.listdir(okra_klasoru):
    dosya_yolu = os.path.join(okra_klasoru, dosya_adi)
    img = load_img(dosya_yolu, target_size=(512, 512))
    img_array = img_to_array(img)
    img_array = img_array/255.0 # Normalizasyon
    X.append(img_array)
    y.append(0)  # Okra sınıfı

# Normal verilerini yükleme ve etiketleme
for dosya_adi in os.listdir(normal_klasoru):
    dosya_yolu = os.path.join(normal_klasoru, dosya_adi)
    img = load_img(dosya_yolu, target_size=(512, 512))
    img_array = img_to_array(img)
    img_array = img_array/255.0 # Normalizasyon
    X.append(img_array)
    y.append(1)  # Normal sınıfı

# Veriyi ve etiketleri Numpy dizilerine dönüştürme
X = np.array(X)
y = np.array(y)

# Verileri karıştırma
sirali_indeksler = np.arange(X.shape[0])
np.random.shuffle(sirali_indeksler)
X = X[sirali_indeksler]
y = y[sirali_indeksler]



# Modeli yükleyip verileri tahmin etme
model = load_model('/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/saved_model/Best Models/Çift_Sinirli_CNN_Model_14_%85, 0.41_.h5', compile=False)
predictions = model.predict(X)  # Verileri tahmin etme

# Gerçek etiketlerin ve tahminlerin hazırlanması
true_labels = y
true_labels_cat = to_categorical(true_labels, num_classes=2)  # Gerçek etiketlerin kategorik hale getirilmesi
pred_prob_cat = predictions  # Tahmin olasılıklarının hesaplanması

# Doğruluk oranını ve kaybı hesaplama
accuracy = accuracy_score(true_labels, np.argmax(predictions, axis=1))
loss = log_loss(true_labels_cat, pred_prob_cat)

print(f"Doğruluk Oranı: {accuracy}")
print(f"Kayıp: {loss}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 19
#      16 y = []
#      18 # Okra verilerini yükleme ve etiketleme
# ---> 19 for dosya_adi in os.listdir(okra_klasoru):
#      20     dosya_yolu = os.path.join(okra_klasoru, dosya_adi)
#      21     img = load_img(dosya_yolu, target_size=(512, 512))
#
# FileNotFoundError: [WinError 3] Sistem belirtilen yolu bulamıyor: '/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Çift_Grafikler/700_Sinirli_Cift/200_Test/Okrali'

# %% [markdown]
# #Her Adımda Accuracy ve Loss Değerlerini Basar

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, log_loss
from keras.preprocessing.image import load_img, img_to_array
from keras.utils import to_categorical
from tensorflow.keras.models import load_model

# Okra ve normal klasörlerinin yolları
okra_klasoru = r"F:\PNG_Datasets\700_Sinirli_Cift\200_Test\Okrali"
normal_klasoru = r"F:\PNG_Datasets\700_Sinirli_Cift\200_Test\Saglikli"

# Verileri ve etiketleri depolamak için boş listeler
X = []
y = []

# Okra verilerini yükleme ve etiketleme
for dosya_adi in os.listdir(okra_klasoru):
    dosya_yolu = os.path.join(okra_klasoru, dosya_adi)
    img = load_img(dosya_yolu, target_size=(512, 512))
    img_array = img_to_array(img)
    X.append(img_array)
    y.append(0)  # Okra sınıfı

# Normal verilerini yükleme ve etiketleme
for dosya_adi in os.listdir(normal_klasoru):
    dosya_yolu = os.path.join(normal_klasoru, dosya_adi)
    img = load_img(dosya_yolu, target_size=(512, 512))
    img_array = img_to_array(img)
    X.append(img_array)
    y.append(1)  # Normal sınıfı

# Veriyi ve etiketleri Numpy dizilerine dönüştürme
X = np.array(X)
y = np.array(y)

# Verileri karıştırma
sirali_indeksler = np.arange(X.shape[0])
np.random.shuffle(sirali_indeksler)
X = X[sirali_indeksler]
y = y[sirali_indeksler]

# Modeli yükleyip verileri tahmin etme
model = load_model(r"C:\Users\AliBakiTURKOZ\OneDrive\Masaüstü\Engineering Project\REPORTS\Deneme_Çift_Sinirli_CNN_Model_15_%83.75, 0.29_.h5", compile = False)  # Kaydedilmiş modeli yükleme
predictions = model.predict(X)  # Verileri tahmin etme

# Gerçek etiketlerin ve tahminlerin hazırlanması
true_labels = y
true_labels_cat = to_categorical(true_labels, num_classes=2)  # Gerçek etiketlerin kategorik hale getirilmesi
pred_prob_cat = predictions  # Tahmin olasılıklarının hesaplanması

# Doğruluk oranını ve kaybı hesaplama
accuracy = accuracy_score(true_labels, np.argmax(predictions, axis=1))
loss = log_loss(true_labels_cat, pred_prob_cat)

print(f"Doğruluk Oranı: {accuracy}")
print(f"Kayıp: {loss}")

# Her aşamadaki tahmin ve gerçek etiketleri yazdırma
print("Tahminler ve Gerçek Etiketler:")
for i in range(len(true_labels)):
    tahmin = 'Okratoksinli' if np.argmax(predictions[i]) == 0 else 'Sağlıklı'
    gerçek_etiket = 'Okratoksinli' if true_labels[i] == 0 else 'Sağlıklı'
    print(f"Tahmin: {tahmin} - Gerçek Etiket: {gerçek_etiket}")

# Accuracy oranlarının yazdırılması
accuracy_list = [accuracy_score(true_labels[:i+1], np.argmax(predictions[:i+1], axis=1)) for i in range(len(true_labels))]
print("Her Aşamadaki Accuracy Oranları:")
for i, acc in enumerate(accuracy_list):
    print(f"Veri sayısı: {i+1}, Accuracy: {acc}")

# Loss ve accuracy grafiğinin çizdirilmesi
loss_list = []
mean_loss_list = []
for i in range(len(true_labels)):
    loss_list.append(log_loss(true_labels_cat[:i+1], pred_prob_cat[:i+1]))
    mean_loss_list.append(np.mean(loss_list))  # Tüm epochlar için loss ortalaması alınıyor

# Accuracy'lerin ortalamasını alalım
mean_accuracy_list = [np.mean(accuracy_list[:i+1]) for i in range(len(accuracy_list))]

plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.plot(range(len(true_labels)), accuracy_list, marker='o', linestyle='-', label='Accuracy')
plt.title('Accuracy')
plt.xlabel('Veri Sayısı')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(range(len(true_labels)), mean_loss_list, marker='o', linestyle='-', label='Mean Loss')
plt.title('Mean Loss')
plt.xlabel('Veri Sayısı')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(range(len(true_labels)), mean_accuracy_list, marker='o', linestyle='-', color='orange', label='Mean Accuracy')
plt.title('Mean Accuracy')
plt.xlabel('Veri Sayısı')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# Doğruluk Oranı: 0.8375
# Kayıp: 0.29630743390979203
# Tahminler ve Gerçek Etiketler:
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Tahmin: Sağlıklı - Gerçek Etiket: Sağlıklı
# Tahmin: Sağlıklı - Gerçek Etiket: Okratoksinli
# Tahmin: Okratoksinli - Gerçek Etiket: Okratoksinli
# Her Aşamadaki Accuracy Oranları:
# Veri sayısı: 1, Accuracy: 1.0
# Veri sayısı: 2, Accuracy: 1.0
# Veri sayısı: 3, Accuracy: 1.0
# Veri sayısı: 4, Accuracy: 1.0
# Veri sayısı: 5, Accuracy: 1.0
# Veri sayısı: 6, Accuracy: 1.0
# Veri sayısı: 7, Accuracy: 1.0
# Veri sayısı: 8, Accuracy: 0.875
# Veri sayısı: 9, Accuracy: 0.8888888888888888
# Veri sayısı: 10, Accuracy: 0.9
# Veri sayısı: 11, Accuracy: 0.9090909090909091
# Veri sayısı: 12, Accuracy: 0.9166666666666666
# Veri sayısı: 13, Accuracy: 0.8461538461538461
# Veri sayısı: 14, Accuracy: 0.8571428571428571
# Veri sayısı: 15, Accuracy: 0.8666666666666667
# Veri sayısı: 16, Accuracy: 0.875
# Veri sayısı: 17, Accuracy: 0.8823529411764706
# Veri sayısı: 18, Accuracy: 0.8888888888888888
# Veri sayısı: 19, Accuracy: 0.8947368421052632
# Veri sayısı: 20, Accuracy: 0.9
# Veri sayısı: 21, Accuracy: 0.9047619047619048
# Veri sayısı: 22, Accuracy: 0.9090909090909091
# Veri sayısı: 23, Accuracy: 0.8695652173913043
# Veri sayısı: 24, Accuracy: 0.8333333333333334
# Veri sayısı: 25, Accuracy: 0.84
# Veri sayısı: 26, Accuracy: 0.8461538461538461
# Veri sayısı: 27, Accuracy: 0.8518518518518519
# Veri sayısı: 28, Accuracy: 0.8571428571428571
# Veri sayısı: 29, Accuracy: 0.8620689655172413
# Veri sayısı: 30, Accuracy: 0.8666666666666667
# Veri sayısı: 31, Accuracy: 0.8709677419354839
# Veri sayısı: 32, Accuracy: 0.875
# Veri sayısı: 33, Accuracy: 0.8484848484848485
# Veri sayısı: 34, Accuracy: 0.8529411764705882
# Veri sayısı: 35, Accuracy: 0.8571428571428571
# Veri sayısı: 36, Accuracy: 0.8611111111111112
# Veri sayısı: 37, Accuracy: 0.8648648648648649
# Veri sayısı: 38, Accuracy: 0.868421052631579
# Veri sayısı: 39, Accuracy: 0.8717948717948718
# Veri sayısı: 40, Accuracy: 0.875
# Veri sayısı: 41, Accuracy: 0.8780487804878049
# Veri sayısı: 42, Accuracy: 0.8809523809523809
# Veri sayısı: 43, Accuracy: 0.8604651162790697
# Veri sayısı: 44, Accuracy: 0.8636363636363636
# Veri sayısı: 45, Accuracy: 0.8666666666666667
# Veri sayısı: 46, Accuracy: 0.8695652173913043
# Veri sayısı: 47, Accuracy: 0.8723404255319149
# Veri sayısı: 48, Accuracy: 0.875
# Veri sayısı: 49, Accuracy: 0.8571428571428571
# Veri sayısı: 50, Accuracy: 0.86
# Veri sayısı: 51, Accuracy: 0.8627450980392157
# Veri sayısı: 52, Accuracy: 0.8653846153846154
# Veri sayısı: 53, Accuracy: 0.8679245283018868
# Veri sayısı: 54, Accuracy: 0.8703703703703703
# Veri sayısı: 55, Accuracy: 0.8727272727272727
# Veri sayısı: 56, Accuracy: 0.875
# Veri sayısı: 57, Accuracy: 0.8771929824561403
# Veri sayısı: 58, Accuracy: 0.8793103448275862
# Veri sayısı: 59, Accuracy: 0.8813559322033898
# Veri sayısı: 60, Accuracy: 0.8833333333333333
# Veri sayısı: 61, Accuracy: 0.8852459016393442
# Veri sayısı: 62, Accuracy: 0.8870967741935484
# Veri sayısı: 63, Accuracy: 0.8888888888888888
# Veri sayısı: 64, Accuracy: 0.890625
# Veri sayısı: 65, Accuracy: 0.8923076923076924
# Veri sayısı: 66, Accuracy: 0.8939393939393939
# Veri sayısı: 67, Accuracy: 0.8805970149253731
# Veri sayısı: 68, Accuracy: 0.8823529411764706
# Veri sayısı: 69, Accuracy: 0.8840579710144928
# Veri sayısı: 70, Accuracy: 0.8857142857142857
# Veri sayısı: 71, Accuracy: 0.8873239436619719
# Veri sayısı: 72, Accuracy: 0.8888888888888888
# Veri sayısı: 73, Accuracy: 0.8904109589041096
# Veri sayısı: 74, Accuracy: 0.8918918918918919
# Veri sayısı: 75, Accuracy: 0.8933333333333333
# Veri sayısı: 76, Accuracy: 0.8947368421052632
# Veri sayısı: 77, Accuracy: 0.8961038961038961
# Veri sayısı: 78, Accuracy: 0.8974358974358975
# Veri sayısı: 79, Accuracy: 0.8987341772151899
# Veri sayısı: 80, Accuracy: 0.8875
# Veri sayısı: 81, Accuracy: 0.8888888888888888
# Veri sayısı: 82, Accuracy: 0.8902439024390244
# Veri sayısı: 83, Accuracy: 0.891566265060241
# Veri sayısı: 84, Accuracy: 0.8928571428571429
# Veri sayısı: 85, Accuracy: 0.8941176470588236
# Veri sayısı: 86, Accuracy: 0.8837209302325582
# Veri sayısı: 87, Accuracy: 0.8850574712643678
# Veri sayısı: 88, Accuracy: 0.8863636363636364
# Veri sayısı: 89, Accuracy: 0.8764044943820225
# Veri sayısı: 90, Accuracy: 0.8777777777777778
# Veri sayısı: 91, Accuracy: 0.8681318681318682
# Veri sayısı: 92, Accuracy: 0.8695652173913043
# Veri sayısı: 93, Accuracy: 0.8709677419354839
# Veri sayısı: 94, Accuracy: 0.8723404255319149
# Veri sayısı: 95, Accuracy: 0.8736842105263158
# Veri sayısı: 96, Accuracy: 0.875
# Veri sayısı: 97, Accuracy: 0.8762886597938144
# Veri sayısı: 98, Accuracy: 0.8775510204081632
# Veri sayısı: 99, Accuracy: 0.8787878787878788
# Veri sayısı: 100, Accuracy: 0.88
# Veri sayısı: 101, Accuracy: 0.8811881188118812
# Veri sayısı: 102, Accuracy: 0.8823529411764706
# Veri sayısı: 103, Accuracy: 0.883495145631068
# Veri sayısı: 104, Accuracy: 0.8846153846153846
# Veri sayısı: 105, Accuracy: 0.8761904761904762
# Veri sayısı: 106, Accuracy: 0.8773584905660378
# Veri sayısı: 107, Accuracy: 0.8785046728971962
# Veri sayısı: 108, Accuracy: 0.8796296296296297
# Veri sayısı: 109, Accuracy: 0.8715596330275229
# Veri sayısı: 110, Accuracy: 0.8727272727272727
# Veri sayısı: 111, Accuracy: 0.8648648648648649
# Veri sayısı: 112, Accuracy: 0.8660714285714286
# Veri sayısı: 113, Accuracy: 0.8672566371681416
# Veri sayısı: 114, Accuracy: 0.8596491228070176
# Veri sayısı: 115, Accuracy: 0.8608695652173913
# Veri sayısı: 116, Accuracy: 0.8620689655172413
# Veri sayısı: 117, Accuracy: 0.8632478632478633
# Veri sayısı: 118, Accuracy: 0.864406779661017
# Veri sayısı: 119, Accuracy: 0.865546218487395
# Veri sayısı: 120, Accuracy: 0.8666666666666667
# Veri sayısı: 121, Accuracy: 0.8677685950413223
# Veri sayısı: 122, Accuracy: 0.8688524590163934
# Veri sayısı: 123, Accuracy: 0.8617886178861789
# Veri sayısı: 124, Accuracy: 0.8629032258064516
# Veri sayısı: 125, Accuracy: 0.856
# Veri sayısı: 126, Accuracy: 0.8571428571428571
# Veri sayısı: 127, Accuracy: 0.8582677165354331
# Veri sayısı: 128, Accuracy: 0.859375
# Veri sayısı: 129, Accuracy: 0.8604651162790697
# Veri sayısı: 130, Accuracy: 0.8615384615384616
# Veri sayısı: 131, Accuracy: 0.8625954198473282
# Veri sayısı: 132, Accuracy: 0.8636363636363636
# Veri sayısı: 133, Accuracy: 0.8646616541353384
# Veri sayısı: 134, Accuracy: 0.8656716417910447
# Veri sayısı: 135, Accuracy: 0.8666666666666667
# Veri sayısı: 136, Accuracy: 0.8602941176470589
# Veri sayısı: 137, Accuracy: 0.8613138686131386
# Veri sayısı: 138, Accuracy: 0.8623188405797102
# Veri sayısı: 139, Accuracy: 0.8561151079136691
# Veri sayısı: 140, Accuracy: 0.8571428571428571
# Veri sayısı: 141, Accuracy: 0.8581560283687943
# Veri sayısı: 142, Accuracy: 0.8591549295774648
# Veri sayısı: 143, Accuracy: 0.8601398601398601
# Veri sayısı: 144, Accuracy: 0.8611111111111112
# Veri sayısı: 145, Accuracy: 0.8620689655172413
# Veri sayısı: 146, Accuracy: 0.863013698630137
# Veri sayısı: 147, Accuracy: 0.8639455782312925
# Veri sayısı: 148, Accuracy: 0.8648648648648649
# Veri sayısı: 149, Accuracy: 0.8657718120805369
# Veri sayısı: 150, Accuracy: 0.86
# Veri sayısı: 151, Accuracy: 0.8609271523178808
# Veri sayısı: 152, Accuracy: 0.8552631578947368
# Veri sayısı: 153, Accuracy: 0.8562091503267973
# Veri sayısı: 154, Accuracy: 0.8571428571428571
# Veri sayısı: 155, Accuracy: 0.8580645161290322
# Veri sayısı: 156, Accuracy: 0.8589743589743589
# Veri sayısı: 157, Accuracy: 0.8598726114649682
# Veri sayısı: 158, Accuracy: 0.8607594936708861
# Veri sayısı: 159, Accuracy: 0.8616352201257862
# Veri sayısı: 160, Accuracy: 0.8625
# Veri sayısı: 161, Accuracy: 0.8633540372670807
# Veri sayısı: 162, Accuracy: 0.8580246913580247
# Veri sayısı: 163, Accuracy: 0.8588957055214724
# Veri sayısı: 164, Accuracy: 0.8597560975609756
# Veri sayısı: 165, Accuracy: 0.8606060606060606
# Veri sayısı: 166, Accuracy: 0.8614457831325302
# Veri sayısı: 167, Accuracy: 0.8622754491017964
# Veri sayısı: 168, Accuracy: 0.8630952380952381
# Veri sayısı: 169, Accuracy: 0.8579881656804734
# Veri sayısı: 170, Accuracy: 0.8588235294117647
# Veri sayısı: 171, Accuracy: 0.8596491228070176
# Veri sayısı: 172, Accuracy: 0.8604651162790697
# Veri sayısı: 173, Accuracy: 0.861271676300578
# Veri sayısı: 174, Accuracy: 0.8620689655172413
# Veri sayısı: 175, Accuracy: 0.8628571428571429
# Veri sayısı: 176, Accuracy: 0.8636363636363636
# Veri sayısı: 177, Accuracy: 0.8587570621468926
# Veri sayısı: 178, Accuracy: 0.8595505617977528
# Veri sayısı: 179, Accuracy: 0.8603351955307262
# Veri sayısı: 180, Accuracy: 0.8611111111111112
# Veri sayısı: 181, Accuracy: 0.861878453038674
# Veri sayısı: 182, Accuracy: 0.8626373626373627
# Veri sayısı: 183, Accuracy: 0.8633879781420765
# Veri sayısı: 184, Accuracy: 0.8641304347826086
# Veri sayısı: 185, Accuracy: 0.8648648648648649
# Veri sayısı: 186, Accuracy: 0.8655913978494624
# Veri sayısı: 187, Accuracy: 0.8663101604278075
# Veri sayısı: 188, Accuracy: 0.8670212765957447
# Veri sayısı: 189, Accuracy: 0.8677248677248677
# Veri sayısı: 190, Accuracy: 0.868421052631579
# Veri sayısı: 191, Accuracy: 0.8691099476439791
# Veri sayısı: 192, Accuracy: 0.8697916666666666
# Veri sayısı: 193, Accuracy: 0.8652849740932642
# Veri sayısı: 194, Accuracy: 0.8608247422680413
# Veri sayısı: 195, Accuracy: 0.8564102564102564
# Veri sayısı: 196, Accuracy: 0.8571428571428571
# Veri sayısı: 197, Accuracy: 0.8578680203045685
# Veri sayısı: 198, Accuracy: 0.8585858585858586
# Veri sayısı: 199, Accuracy: 0.8592964824120602
# Veri sayısı: 200, Accuracy: 0.86
# Veri sayısı: 201, Accuracy: 0.8606965174129353
# Veri sayısı: 202, Accuracy: 0.8613861386138614
# Veri sayısı: 203, Accuracy: 0.8620689655172413
# Veri sayısı: 204, Accuracy: 0.8627450980392157
# Veri sayısı: 205, Accuracy: 0.8585365853658536
# Veri sayısı: 206, Accuracy: 0.8543689320388349
# Veri sayısı: 207, Accuracy: 0.855072463768116
# Veri sayısı: 208, Accuracy: 0.8557692307692307
# Veri sayısı: 209, Accuracy: 0.8564593301435407
# Veri sayısı: 210, Accuracy: 0.8571428571428571
# Veri sayısı: 211, Accuracy: 0.8578199052132701
# Veri sayısı: 212, Accuracy: 0.8584905660377359
# Veri sayısı: 213, Accuracy: 0.8591549295774648
# Veri sayısı: 214, Accuracy: 0.8598130841121495
# Veri sayısı: 215, Accuracy: 0.8604651162790697
# Veri sayısı: 216, Accuracy: 0.8611111111111112
# Veri sayısı: 217, Accuracy: 0.8617511520737328
# Veri sayısı: 218, Accuracy: 0.8577981651376146
# Veri sayısı: 219, Accuracy: 0.8584474885844748
# Veri sayısı: 220, Accuracy: 0.8590909090909091
# Veri sayısı: 221, Accuracy: 0.8597285067873304
# Veri sayısı: 222, Accuracy: 0.8603603603603603
# Veri sayısı: 223, Accuracy: 0.8609865470852018
# Veri sayısı: 224, Accuracy: 0.8616071428571429
# Veri sayısı: 225, Accuracy: 0.8622222222222222
# Veri sayısı: 226, Accuracy: 0.8628318584070797
# Veri sayısı: 227, Accuracy: 0.8634361233480177
# Veri sayısı: 228, Accuracy: 0.8596491228070176
# Veri sayısı: 229, Accuracy: 0.8602620087336245
# Veri sayısı: 230, Accuracy: 0.8608695652173913
# Veri sayısı: 231, Accuracy: 0.8614718614718615
# Veri sayısı: 232, Accuracy: 0.8577586206896551
# Veri sayısı: 233, Accuracy: 0.8583690987124464
# Veri sayısı: 234, Accuracy: 0.8589743589743589
# Veri sayısı: 235, Accuracy: 0.8595744680851064
# Veri sayısı: 236, Accuracy: 0.8601694915254238
# Veri sayısı: 237, Accuracy: 0.8607594936708861
# Veri sayısı: 238, Accuracy: 0.8613445378151261
# Veri sayısı: 239, Accuracy: 0.8619246861924686
# Veri sayısı: 240, Accuracy: 0.8583333333333333
# Veri sayısı: 241, Accuracy: 0.8547717842323651
# Veri sayısı: 242, Accuracy: 0.8553719008264463
# Veri sayısı: 243, Accuracy: 0.8559670781893004
# Veri sayısı: 244, Accuracy: 0.8565573770491803
# Veri sayısı: 245, Accuracy: 0.8571428571428571
# Veri sayısı: 246, Accuracy: 0.8577235772357723
# Veri sayısı: 247, Accuracy: 0.8582995951417004
# Veri sayısı: 248, Accuracy: 0.8588709677419355
# Veri sayısı: 249, Accuracy: 0.8594377510040161
# Veri sayısı: 250, Accuracy: 0.856
# Veri sayısı: 251, Accuracy: 0.8565737051792829
# Veri sayısı: 252, Accuracy: 0.8571428571428571
# Veri sayısı: 253, Accuracy: 0.857707509881423
# Veri sayısı: 254, Accuracy: 0.8543307086614174
# Veri sayısı: 255, Accuracy: 0.8549019607843137
# Veri sayısı: 256, Accuracy: 0.8515625
# Veri sayısı: 257, Accuracy: 0.8521400778210116
# Veri sayısı: 258, Accuracy: 0.8527131782945736
# Veri sayısı: 259, Accuracy: 0.8532818532818532
# Veri sayısı: 260, Accuracy: 0.8538461538461538
# Veri sayısı: 261, Accuracy: 0.8505747126436781
# Veri sayısı: 262, Accuracy: 0.851145038167939
# Veri sayısı: 263, Accuracy: 0.8517110266159695
# Veri sayısı: 264, Accuracy: 0.8522727272727273
# Veri sayısı: 265, Accuracy: 0.8528301886792453
# Veri sayısı: 266, Accuracy: 0.8533834586466166
# Veri sayısı: 267, Accuracy: 0.8539325842696629
# Veri sayısı: 268, Accuracy: 0.8544776119402985
# Veri sayısı: 269, Accuracy: 0.8513011152416357
# Veri sayısı: 270, Accuracy: 0.8481481481481481
# Veri sayısı: 271, Accuracy: 0.8487084870848709
# Veri sayısı: 272, Accuracy: 0.8492647058823529
# Veri sayısı: 273, Accuracy: 0.8498168498168498
# Veri sayısı: 274, Accuracy: 0.8467153284671532
# Veri sayısı: 275, Accuracy: 0.8472727272727273
# Veri sayısı: 276, Accuracy: 0.8478260869565217
# Veri sayısı: 277, Accuracy: 0.8483754512635379
# Veri sayısı: 278, Accuracy: 0.8489208633093526
# Veri sayısı: 279, Accuracy: 0.8494623655913979
# Veri sayısı: 280, Accuracy: 0.85
# Veri sayısı: 281, Accuracy: 0.8469750889679716
# Veri sayısı: 282, Accuracy: 0.8475177304964538
# Veri sayısı: 283, Accuracy: 0.8480565371024735
# Veri sayısı: 284, Accuracy: 0.8485915492957746
# Veri sayısı: 285, Accuracy: 0.8456140350877193
# Veri sayısı: 286, Accuracy: 0.8461538461538461
# Veri sayısı: 287, Accuracy: 0.8466898954703833
# Veri sayısı: 288, Accuracy: 0.8472222222222222
# Veri sayısı: 289, Accuracy: 0.8477508650519031
# Veri sayısı: 290, Accuracy: 0.8482758620689655
# Veri sayısı: 291, Accuracy: 0.845360824742268
# Veri sayısı: 292, Accuracy: 0.8458904109589042
# Veri sayısı: 293, Accuracy: 0.8464163822525598
# Veri sayısı: 294, Accuracy: 0.8469387755102041
# Veri sayısı: 295, Accuracy: 0.8440677966101695
# Veri sayısı: 296, Accuracy: 0.8445945945945946
# Veri sayısı: 297, Accuracy: 0.8451178451178452
# Veri sayısı: 298, Accuracy: 0.8456375838926175
# Veri sayısı: 299, Accuracy: 0.8461538461538461
# Veri sayısı: 300, Accuracy: 0.8466666666666667
# Veri sayısı: 301, Accuracy: 0.8471760797342193
# Veri sayısı: 302, Accuracy: 0.847682119205298
# Veri sayısı: 303, Accuracy: 0.8481848184818482
# Veri sayısı: 304, Accuracy: 0.8486842105263158
# Veri sayısı: 305, Accuracy: 0.8491803278688524
# Veri sayısı: 306, Accuracy: 0.8496732026143791
# Veri sayısı: 307, Accuracy: 0.8501628664495114
# Veri sayısı: 308, Accuracy: 0.8474025974025974
# Veri sayısı: 309, Accuracy: 0.8478964401294499
# Veri sayısı: 310, Accuracy: 0.8483870967741935
# Veri sayısı: 311, Accuracy: 0.8456591639871383
# Veri sayısı: 312, Accuracy: 0.842948717948718
# Veri sayısı: 313, Accuracy: 0.8434504792332268
# Veri sayısı: 314, Accuracy: 0.8439490445859873
# Veri sayısı: 315, Accuracy: 0.8412698412698413
# Veri sayısı: 316, Accuracy: 0.8417721518987342
# Veri sayısı: 317, Accuracy: 0.8422712933753943
# Veri sayısı: 318, Accuracy: 0.8427672955974843
# Veri sayısı: 319, Accuracy: 0.8432601880877743
# Veri sayısı: 320, Accuracy: 0.84375
# Veri sayısı: 321, Accuracy: 0.8411214953271028
# Veri sayısı: 322, Accuracy: 0.8416149068322981
# Veri sayısı: 323, Accuracy: 0.8421052631578947
# Veri sayısı: 324, Accuracy: 0.8425925925925926
# Veri sayısı: 325, Accuracy: 0.84
# Veri sayısı: 326, Accuracy: 0.8404907975460123
# Veri sayısı: 327, Accuracy: 0.8409785932721713
# Veri sayısı: 328, Accuracy: 0.8414634146341463
# Veri sayısı: 329, Accuracy: 0.8419452887537994
# Veri sayısı: 330, Accuracy: 0.8424242424242424
# Veri sayısı: 331, Accuracy: 0.8429003021148036
# Veri sayısı: 332, Accuracy: 0.8433734939759037
# Veri sayısı: 333, Accuracy: 0.8438438438438438
# Veri sayısı: 334, Accuracy: 0.8413173652694611
# Veri sayısı: 335, Accuracy: 0.8417910447761194
# Veri sayısı: 336, Accuracy: 0.8392857142857143
# Veri sayısı: 337, Accuracy: 0.8397626112759644
# Veri sayısı: 338, Accuracy: 0.8372781065088757
# Veri sayısı: 339, Accuracy: 0.8377581120943953
# Veri sayısı: 340, Accuracy: 0.8382352941176471
# Veri sayısı: 341, Accuracy: 0.8387096774193549
# Veri sayısı: 342, Accuracy: 0.8391812865497076
# Veri sayısı: 343, Accuracy: 0.8396501457725948
# Veri sayısı: 344, Accuracy: 0.8401162790697675
# Veri sayısı: 345, Accuracy: 0.8405797101449275
# Veri sayısı: 346, Accuracy: 0.8410404624277457
# Veri sayısı: 347, Accuracy: 0.8414985590778098
# Veri sayısı: 348, Accuracy: 0.8390804597701149
# Veri sayısı: 349, Accuracy: 0.839541547277937
# Veri sayısı: 350, Accuracy: 0.84
# Veri sayısı: 351, Accuracy: 0.8404558404558404
# Veri sayısı: 352, Accuracy: 0.8409090909090909
# Veri sayısı: 353, Accuracy: 0.8413597733711048
# Veri sayısı: 354, Accuracy: 0.8418079096045198
# Veri sayısı: 355, Accuracy: 0.8422535211267606
# Veri sayısı: 356, Accuracy: 0.8426966292134831
# Veri sayısı: 357, Accuracy: 0.8431372549019608
# Veri sayısı: 358, Accuracy: 0.8435754189944135
# Veri sayısı: 359, Accuracy: 0.841225626740947
# Veri sayısı: 360, Accuracy: 0.8388888888888889
# Veri sayısı: 361, Accuracy: 0.8393351800554016
# Veri sayısı: 362, Accuracy: 0.8370165745856354
# Veri sayısı: 363, Accuracy: 0.837465564738292
# Veri sayısı: 364, Accuracy: 0.8351648351648352
# Veri sayısı: 365, Accuracy: 0.8356164383561644
# Veri sayısı: 366, Accuracy: 0.8360655737704918
# Veri sayısı: 367, Accuracy: 0.8365122615803815
# Veri sayısı: 368, Accuracy: 0.8369565217391305
# Veri sayısı: 369, Accuracy: 0.8373983739837398
# Veri sayısı: 370, Accuracy: 0.8378378378378378
# Veri sayısı: 371, Accuracy: 0.8355795148247979
# Veri sayısı: 372, Accuracy: 0.8360215053763441
# Veri sayısı: 373, Accuracy: 0.8337801608579088
# Veri sayısı: 374, Accuracy: 0.8342245989304813
# Veri sayısı: 375, Accuracy: 0.8346666666666667
# Veri sayısı: 376, Accuracy: 0.8324468085106383
# Veri sayısı: 377, Accuracy: 0.8328912466843501
# Veri sayısı: 378, Accuracy: 0.8333333333333334
# Veri sayısı: 379, Accuracy: 0.8337730870712401
# Veri sayısı: 380, Accuracy: 0.8342105263157895
# Veri sayısı: 381, Accuracy: 0.8320209973753281
# Veri sayısı: 382, Accuracy: 0.8324607329842932
# Veri sayısı: 383, Accuracy: 0.8328981723237598
# Veri sayısı: 384, Accuracy: 0.8333333333333334
# Veri sayısı: 385, Accuracy: 0.8337662337662337
# Veri sayısı: 386, Accuracy: 0.8341968911917098
# Veri sayısı: 387, Accuracy: 0.834625322997416
# Veri sayısı: 388, Accuracy: 0.8350515463917526
# Veri sayısı: 389, Accuracy: 0.8354755784061697
# Veri sayısı: 390, Accuracy: 0.8358974358974359
# Veri sayısı: 391, Accuracy: 0.8363171355498721
# Veri sayısı: 392, Accuracy: 0.8367346938775511
# Veri sayısı: 393, Accuracy: 0.8371501272264631
# Veri sayısı: 394, Accuracy: 0.8375634517766497
# Veri sayısı: 395, Accuracy: 0.8379746835443038
# Veri sayısı: 396, Accuracy: 0.8383838383838383
# Veri sayısı: 397, Accuracy: 0.8387909319899244
# Veri sayısı: 398, Accuracy: 0.8391959798994975
# Veri sayısı: 399, Accuracy: 0.8370927318295739
# Veri sayısı: 400, Accuracy: 0.8375
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# C:\Users\AliBakiTURKOZ\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:2942: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(

# %% [markdown]
# #DENEME RASPBERRY İÇİN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix

# Öncelikle modeli ve veri setini yükleyelim
model = tf.keras.models.load_model('/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/saved_model/Deneme_Çift_CNN_Model_7_.h5')  # Model dosyasının adını ve yolunu ayarlayın
test_dir = '/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Çift_Grafikler/200_TEST_DATASET_ÇİFTGRAFİK_512x512'  # Test veri setinin dizinini ayarlayın

# Test veri setindeki görüntüleri yükleme ve ön işleme fonksiyonu
def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(512, 512))
    img_array = image.img_to_array(img)
    img_array = preprocess_input(img_array)
    return np.expand_dims(img_array, axis=0)

# Test veri setini yükleme ve modeli değerlendirme
def evaluate_model(test_dir):
    test_datagen = image.ImageDataGenerator(preprocessing_function=preprocess_input)
    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(512, 512),
        batch_size=1,
        class_mode='binary',  # İki sınıf olduğu için 'binary' olarak ayarlayın
        shuffle=False
    )

    # Modeli değerlendirme
    loss, accuracy = model.evaluate(test_generator)

    print("Doğruluk:", accuracy)
    print("Kayıp:", loss)

    # Tahminleri ve gerçek etiketleri alarak bir sınıflandırma raporu oluşturma
    y_true = test_generator.classes
    y_pred = model.predict(test_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Sınıflandırma Raporu:")
    print(classification_report(y_true, y_pred))

# Modeli ve test veri setini değerlendirme
evaluate_model(test_dir)
# Out:
# Found 400 images belonging to 2 classes.
# 400/400 [==============================] - 112s 280ms/step - loss: 0.7621 - accuracy: 0.5750
# Doğruluk: 0.574999988079071
# Kayıp: 0.7620721459388733
# 400/400 [==============================] - 93s 231ms/step
# Sınıflandırma Raporu:
#               precision    recall  f1-score   support
#
#            0       1.00      0.15      0.26       200
#            1       0.54      1.00      0.70       200
#
#     accuracy                           0.57       400
#    macro avg       0.77      0.57      0.48       400
# weighted avg       0.77      0.57      0.48       400

# %%
# HAN BEY SİSTEMİNDEKİ MODEL TEST KODU

import os
import numpy as np
from sklearn.metrics import accuracy_score, log_loss
from keras.preprocessing.image import load_img, img_to_array
from keras.utils import to_categorical
from tensorflow.keras.models import load_model

# Okra ve normal klasörlerinin yolları
okra_klasoru = "/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Çift_Grafikler/700_Sinirsiz_Cift/200_Test/Okrali"
normal_klasoru = "/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/Data_Sets/Grafikler/Çift_Grafikler/700_Sinirsiz_Cift/200_Test/Saglikli"

# Verileri ve etiketleri depolamak için boş listeler
X = []
y = []

# Okra verilerini yükleme ve etiketleme
for dosya_adi in os.listdir(okra_klasoru):
    dosya_yolu = os.path.join(okra_klasoru, dosya_adi)
    img = load_img(dosya_yolu, target_size=(512, 512))
    img_array = img_to_array(img)
    X.append(img_array)
    y.append(0)  # Okra sınıfı

# Normal verilerini yükleme ve etiketleme
for dosya_adi in os.listdir(normal_klasoru):
    dosya_yolu = os.path.join(normal_klasoru, dosya_adi)
    img = load_img(dosya_yolu, target_size=(512, 512))
    img_array = img_to_array(img)
    X.append(img_array)
    y.append(1)  # Normal sınıfı

# Veriyi ve etiketleri Numpy dizilerine dönüştürme
X = np.array(X)
y = np.array(y)

# Verileri karıştırma
sirali_indeksler = np.arange(X.shape[0])
np.random.shuffle(sirali_indeksler)
X = X[sirali_indeksler]
y = y[sirali_indeksler]

# Modeli yükleyip verileri tahmin etme
model = load_model('/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/saved_model/HAN BEY SISTEMINDEKI VERILER VE MODELLER/Sinirsiz_Cift_Best_Result/Sinirsiz_Cift_83.25_0.38.h5')  # Kaydedilmiş modeli yükleme
predictions = model.predict(X)  # Verileri tahmin etme

# Gerçek etiketlerin ve tahminlerin hazırlanması
true_labels = y
true_labels_cat = to_categorical(true_labels, num_classes=2)  # Gerçek etiketlerin kategorik hale getirilmesi
pred_prob_cat = predictions  # Tahmin olasılıklarının hesaplanması

# Doğruluk oranını ve kaybı hesaplama
accuracy = accuracy_score(true_labels, np.argmax(predictions, axis=1))
loss = log_loss(true_labels_cat, pred_prob_cat)

print(f"Doğruluk Oranı: {accuracy}")
print(f"Kayıp: {loss}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-708ead304f61> in <cell line: 45>()
#      43
#      44 # Modeli yükleyip verileri tahmin etme
# ---> 45 model = load_model('/content/drive/MyDrive/AliBaki_TURKOZ_Engineering_Project/saved_model/HAN BEY SISTEMINDEKI VERILER VE MODELLER/Sinirsiz_Cift_Best_Result/Sinirsiz_Cift_83.25_0.38.h5')  # Kaydedilmiş modeli yükleme
#      46 predictions = model.predict(X)  # Verileri tahmin etme
#      47
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in from_config(cls, config)
#     868             return cls(**config)
#     869         except Exception as e:
# --> 870             raise TypeError(
#     871                 f"Error when deserializing class '{cls.__name__}' using "
#     872                 f"config={config}.\n\nException encountered: {e}"
#
# TypeError: Error when deserializing class 'InputLayer' using config={'batch_shape': [32, 512, 512, 3], 'dtype': 'float32', 'sparse': False, 'name': 'input_layer'}.
#
# Exception encountered: Unrecognized keyword arguments: ['batch_shape']
